# %%
from sepal_ui import sepalwidgets as sw

#create the Html body of your about section 
pathname = 'utils/about.md' #path to your markdown file
ts_about = sw.TileAbout(pathname)
ts_about

# %%
#create a disclaimer
ts_disclaimer = sw.TileDisclaimer()
ts_disclaimer
